# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
pwd
# Out:
# 'C:\\Users\\hkvij\\upgrad'

# %%
loan=pd.read_csv("C:/Users/hkvij/Desktop/upgrad/Assignment 1/loan/loan.csv", encoding='Latin-1')
# Out:
# C:\Users\hkvij\AppData\Local\Temp\ipykernel_10616\2470424895.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan=pd.read_csv("C:/Users/hkvij/Desktop/upgrad/Assignment 1/loan/loan.csv", encoding='Latin-1')

# %% [markdown]
#  # Basic Informations

# %%
loan.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# ...

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
loan.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
loan.loc[100:300,['loan_amnt','term','int_rate','installment','loan_status','emp_length']]
# Out:
#      loan_amnt        term int_rate  installment  loan_status emp_length
# 100       6200   36 months    9.91%       199.80  Charged Off    2 years
# 101      16000   60 months   17.58%       402.65      Current    7 years
# 102       6000   36 months    8.90%       190.52   Fully Paid    8 years
# 103       7200   36 months    9.91%       232.02   Fully Paid    6 years
# 104       9500   36 months    8.90%       301.66   Fully Paid    7 years
# ..         ...         ...      ...          ...          ...        ...
# 296      14400   36 months   11.71%       476.30   Fully Paid     1 year
# 297      10000   36 months   12.42%       334.16   Fully Paid  10+ years
# 298       8000   36 months   11.71%       264.61   Fully Paid     1 year
# 299       8000   36 months   16.29%       282.41  Charged Off    5 years
# 300      30000   60 months   12.42%       673.72  Charged Off    3 years
#
# [201 rows x 6 columns]

# %%
loan.loc[301:599,['loan_amnt','term','int_rate','installment','loan_status','emp_length']]
# Out:
#      loan_amnt        term int_rate  installment  loan_status emp_length
# 301      18000   60 months   16.77%       445.13  Charged Off    6 years
# 302      13250   36 months   11.71%       438.26   Fully Paid    2 years
# 303      14000   36 months   14.27%       480.33   Fully Paid    6 years
# 304      20000   60 months   20.30%       533.23  Charged Off  10+ years
# 305      10000   36 months   16.29%       353.01   Fully Paid  10+ years
# ..         ...         ...      ...          ...          ...        ...
# 595       1800   36 months   12.42%        60.15   Fully Paid    7 years
# 596      22200   36 months   19.42%       818.49  Charged Off    2 years
# 597      21400   60 months   19.42%       560.09   Fully Paid    3 years
# 598      13000   36 months    7.90%       406.78  Charged Off  10+ years
# 599       8000   36 months   12.69%       268.36   Fully Paid    5 years
#
# [299 rows x 6 columns]

# %%
loan['term'].value_counts()
# Out:
# term
#  36 months    29096
#  60 months    10621
# Name: count, dtype: int64

# %%
loan['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: count, dtype: int64

# %%
loan.nsmallest(10,'loan_amnt')
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 38863  312505     312443        500          500            450.0   36 months
# 39275  242695     242682        500          500            500.0   36 months
# 39373  216698     174214        500          500            500.0   36 months
# 39397  211133     210644        500          500            475.0   36 months
# 39544  164346     163835        500          500            400.0   36 months
# 38899  306018     305720        700          700            700.0   36 months
# 38867  311591     311571        725          725            650.0   36 months
# 39211  253227     253223        750          750            725.0   36 months
# 39262  244029     244014        800          800            800.0   36 months
# 39143  262961     262933        900          900            875.0   36 months
#
#       int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# ...

# %%
loan.nlargest(10,'loan_amnt')
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 80   1068994    1303432      35000        22075      22050.00000   60 months
# 128  1068159    1302729      35000        35000      35000.00000   36 months
# 185  1067084    1301459      35000        35000      35000.00000   36 months
# 268  1066155    1277661      35000        26825      26800.00000   60 months
# 276  1065896    1300036      35000        35000      35000.00000   36 months
# 306  1061681    1293700      35000        23250      23200.00000   60 months
# 336  1065110    1299187      35000        23150      21739.74813   60 months
# 387  1053765    1285367      35000        27575      26043.43249   60 months
# 431  1057239    1288798      35000        35000      32763.05520   60 months
# 496  1063393    1295948      35000        23250      23225.00000   60 months
#
#     int_rate  installment grade sub_grade  \
# 80    17.27%       551.84     D        D3
# ...

# %% [markdown]
# # Data Analysis and Recommentations

# %%
loan.drop(['id','member_id'],axis=1,inplace=True)

# %%
loan.dropna(subset=['emp_length'],inplace=True)

# %%
# loan
round((loan.isnull().sum()/loan.shape[0])*100,2)
# Out:
# loan_amnt                       0.0
# funded_amnt                     0.0
# funded_amnt_inv                 0.0
# term                            0.0
# int_rate                        0.0
#                               ...
# tax_liens                       0.1
# tot_hi_cred_lim               100.0
# total_bal_ex_mort             100.0
# total_bc_limit                100.0
# total_il_high_credit_limit    100.0
# Length: 109, dtype: float64

# %%
loan["int_rate"] = loan['int_rate'].apply(lambda x: float(x.split("%")[0])) #remove %
loan["int_rate"]
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 38642, dtype: float64

# %%
loan["term"] = loan['term'].apply(lambda x: float(x.split("months")[0])) #remove %
loan["term"]
# Out:
# 0        36.0
# 1        60.0
# 2        36.0
# 3        36.0
# 4        60.0
#          ...
# 39712    36.0
# 39713    36.0
# 39714    36.0
# 39715    36.0
# 39716    36.0
# Name: term, Length: 38642, dtype: float64

# %%
loan["int_rate"].describe()
# Out:
# count    38642.000000
# mean        12.052427
# std          3.716705
# min          5.420000
# 25%          9.320000
# 50%         11.860000
# 75%         14.590000
# max         24.590000
# Name: int_rate, dtype: float64

# %%
loan["annual_inc"].describe()
# Out:
# count    3.864200e+04
# mean     6.960828e+04
# std      6.425320e+04
# min      4.000000e+03
# 25%      4.140000e+04
# 50%      6.000000e+04
# 75%      8.319999e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
#catagorizing annual income
def annual_inc(x):
    if x<=50000:
        return 'low income'
    elif x>50000 and x<=100000:
        return 'Medium income'
    else:
        return 'High income'

# %%
loan['annual_inc']=loan['annual_inc'].apply(lambda x:annual_inc(x))
loan['annual_inc']
# Out:
# 0           low income
# 1           low income
# 2           low income
# 3           low income
# 4        Medium income
#              ...
# 39712      High income
# 39713       low income
# 39714    Medium income
# 39715      High income
# 39716       low income
# Name: annual_inc, Length: 38642, dtype: object

# %%
#categorizing int_rates
def intrest(x):
    if x<8:
        return 'Low intrest'
    elif x>8 and x<14:
        return 'Medium intrest'
    else:
        return 'High intrest'

# %%
loan['int_rate']=loan['int_rate'].apply(lambda x:int_rate(x))
loan['int_rate']
# Out:
# 0        Medium intrest
# 1          High intrest
# 2          High intrest
# 3        Medium intrest
# 4        Medium intrest
#               ...
# 39712    Medium intrest
# 39713    Medium intrest
# 39714    Medium intrest
# 39715       Low intrest
# 39716    Medium intrest
# Name: int_rate, Length: 38642, dtype: object

# %%
loan['int_rate'].unique()
# Out:
# array(['Medium intrest', 'High intrest', 'Low intrest'], dtype=object)

# %%
loan['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5399
# Current         1098
# Name: count, dtype: int64

# %%
loan_final=loan[~(loan['loan_status']=="Current")]
loan_final.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term        int_rate  installment  \
# 0       5000         5000           4975.0  36.0  Medium intrest       162.87
# 1       2500         2500           2500.0  60.0    High intrest        59.83
# 2       2400         2400           2400.0  36.0    High intrest        84.33
# 3      10000        10000          10000.0  36.0  Medium intrest       339.31
# 5       5000         5000           5000.0  36.0     Low intrest       156.46
#
#   grade sub_grade             emp_title emp_length  ... num_tl_90g_dpd_24m  \
# 0     B        B2                   NaN  10+ years  ...                NaN
# 1     C        C4                 Ryder   < 1 year  ...                NaN
# 2     C        C5                   NaN  10+ years  ...                NaN
# 3     C        C1   AIR RESOURCES BOARD  10+ years  ...                NaN
# 5     A        A4  Veolia Transportaton    3 years  ...                NaN
#
# ...

# %% [markdown]
# # Univariate Analysis

# %%
def cat_analysis(x,):
  print(loan_final[str(x)].value_counts())

# %%
cat_analysis('loan_status')
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5399
# Name: count, dtype: int64

# %%
cat_analysis('int_rate')
# Out:
# int_rate
# Medium intrest    19252
# High intrest      10620
# Low intrest        7672
# Name: count, dtype: int64

# %%
cat_analysis('purpose')
# Out:
# purpose
# debt_consolidation    17675
# credit_card            4899
# other                  3713
# home_improvement       2785
# major_purchase         2080
# small_business         1710
# car                    1448
# wedding                 913
# medical                 656
# moving                  552
# house                   354
# vacation                348
# educational             317
# renewable_energy         94
# Name: count, dtype: int64

# %%
loan_final['loan_amnt'].max()
# Out:
# 35000

# %%
loan_final['loan_amnt'].min()
# Out:
# 500

# %%
loan_final['loan_amnt'].mean()
# Out:
# 11119.329986149585

# %% [markdown]
# # Bi-Variate Analysis

# %%
loan_final.groupby(['loan_status','int_rate']).size().reset_index(name='Count')
# Out:
#    loan_status        int_rate  Count
# 0  Charged Off    High intrest   2505
# 1  Charged Off     Low intrest    390
# 2  Charged Off  Medium intrest   2504
# 3   Fully Paid    High intrest   8115
# 4   Fully Paid     Low intrest   7282
# 5   Fully Paid  Medium intrest  16748

# %% [markdown]
# # Highly Recommended to conduct immense background verification who takes the loan in high intrest rates.

# %%
loan_final.groupby(['loan_status','annual_inc','term']).size()
# Out:
# loan_status  annual_inc     term
# Charged Off  High income    36.0      298
#                             60.0      291
#              Medium income  36.0     1227
#                             60.0     1145
#              low income     36.0     1548
#                             60.0      890
# Fully Paid   High income    36.0     3574
#                             60.0     1270
#              Medium income  36.0    11556
#                             60.0     3505
#              low income     36.0    10084
#                             60.0     2156
# dtype: int64

# %%
loan_final.groupby(['loan_status','annual_inc','term']).size().reset_index(name='count').sort_values('count',ascending=False)
# Out:
#     loan_status     annual_inc  term  count
# 8    Fully Paid  Medium income  36.0  11556
# 10   Fully Paid     low income  36.0  10084
# 6    Fully Paid    High income  36.0   3574
# 9    Fully Paid  Medium income  60.0   3505
# 11   Fully Paid     low income  60.0   2156
# 4   Charged Off     low income  36.0   1548
# 7    Fully Paid    High income  60.0   1270
# 2   Charged Off  Medium income  36.0   1227
# 3   Charged Off  Medium income  60.0   1145
# 5   Charged Off     low income  60.0    890
# 0   Charged Off    High income  36.0    298
# 1   Charged Off    High income  60.0    291

# %%
loan_final.groupby(['loan_status','annual_inc','int_rate']).size()
# Out:
# loan_status  annual_inc     int_rate
# Charged Off  High income    High intrest       339
#                             Low intrest         23
#                             Medium intrest     227
#              Medium income  High intrest      1195
#                             Low intrest        150
#                             Medium intrest    1027
#              low income     High intrest       971
#                             Low intrest        217
#                             Medium intrest    1250
# Fully Paid   High income    High intrest      1461
#                             Low intrest        978
#                             Medium intrest    2405
#              Medium income  High intrest      3816
#                             Low intrest       3571
#                             Medium intrest    7674
#              low income     High intrest      2838
#                             Low intrest       2733
#                             Medium intrest    6669
# ...

# %%
loan.groupby(['loan_status', 'verification_status']).size()
# Out:
# loan_status  verification_status
# Charged Off  Not Verified            2049
#              Source Verified         1396
#              Verified                1954
# Current      Not Verified             220
#              Source Verified          297
#              Verified                 581
# Fully Paid   Not Verified           14229
#              Source Verified         8098
#              Verified                9818
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
loan_final
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term        int_rate  \
# 0           5000         5000           4975.0   36 months  Medium intrest
# 1           2500         2500           2500.0   60 months    High intrest
# 2           2400         2400           2400.0   36 months    High intrest
# 3          10000        10000          10000.0   36 months  Medium intrest
# 5           5000         5000           5000.0   36 months     Low intrest
# ...          ...          ...              ...         ...             ...
# 39712       2500         2500           1075.0   36 months  Medium intrest
# 39713       8500         8500            875.0   36 months  Medium intrest
# 39714       5000         5000           1325.0   36 months  Medium intrest
# 39715       5000         5000            650.0   36 months     Low intrest
# 39716       7500         7500            800.0   36 months  Medium intrest
#
# ...

# %%
sns.distplot(loan_final['loan_amnt'])
# Out:
# C:\Users\hkvij\AppData\Local\Temp\ipykernel_10616\1825346442.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(loan_final['loan_amnt'])
# <Axes: xlabel='loan_amnt', ylabel='Density'>

# %%
sns.distplot(loan_final['installment'])
# Out:
# C:\Users\hkvij\AppData\Local\Temp\ipykernel_10616\484206769.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(loan_final['installment'])
# <Axes: xlabel='installment', ylabel='Density'>

# %%
sns.histplot(loan_final['loan_amnt'])
# Out:
# <Axes: xlabel='loan_amnt', ylabel='Count'>

# %%
sns.countplot(data=loan_final,x="loan_status",hue="term")
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
sns.countplot(x=loan_final['loan_status'])
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
sns.countplot(x=loan_final['int_rate'])
# Out:
# <Axes: xlabel='int_rate', ylabel='count'>

# %%
sns.countplot(x=loan_final['verification_status'])
plt.title("Proper verification of Applications and documents will reduce the occurance of Defaulters.")
# Out:
# <Axes: xlabel='verification_status', ylabel='count'>
# Text(0.5, 1.0, 'Proper verification of Applications and documents will reduce the occurance of Defaulters.')

# %%
plt.figure(figsize=(25,10))
sns.countplot(x=loan_final['purpose'])
plt.title("Most of the loan took for the debt_consolidation. So it is highly recommended to check the applicant's pending loan payments")
#Most of the loan took for the debt_consolidation
# Out:
# <Axes: xlabel='purpose', ylabel='count'>
# Text(0.5, 1.0, "Most of the loan took for the debt_consolidation. So it is highly recommended to check the applicant's pending loan payments")

# %%
sns.countplot(data=loan_final,x="loan_status",hue="annual_inc")
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
sns.countplot(data=loan_final,x="loan_status",hue="int_rate")
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
sns.countplot(data=loan_final,x="loan_status",hue="term")
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
pwd
# Out:
# 'C:\\Users\\hkvij\\upgrad'
